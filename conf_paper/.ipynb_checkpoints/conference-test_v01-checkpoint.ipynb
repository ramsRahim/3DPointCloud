# %%
import os
import sys
sys.path.append('../../Project_Clustering')

import numpy as np
import pandas as pd
import pickle 
from matplotlib import cm
import matplotlib.pyplot as plt
from sklearn import preprocessing
from scipy.interpolate import griddata
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
import myClusterPackage as myPack
from sklearn.mixture import GaussianMixture
from mySpectralClustering import spectralFeatures
import myKmeans as Kmeans
from multiprocessing import Pool

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import seaborn as sns
import time

# %% [markdown]
# ## Extracting point cloud features

# %%
#face_db = []
#face_list = []
#labels = []


#data_folder = os.listdir("../3DFACEPAPER/Data/") # list of all subfolder within Data folder
#data_folder.remove('.DS_Store') 


#for k, expressions in enumerate (data_folder): # will loop within the main folder
   
    # Accessing each subfolder (expression) within the data folder  
#    path =  "../3DFACEPAPER/Data/" + expressions +"/"
#    face_names = os.listdir(path)    # list of all file names within subfolder
    
   
#    for face in face_names: # will loop within the subfolder
        
#        if not face.startswith('.'):
       # import the face and face labels
#            file_name = path + face
        
#            df_face = pd.read_csv(file_name)
#            face_list.append (df_face.values)
#            labels.append (expressions)
            

#pickle.dump(face_list, open('face_data_full','wb'))
#pickle.dump (labels, open('face_labels_full', 'wb'))

# %%
face_list = pickle.load(open('face_data_full', 'rb'))
face_labels = pickle.load(open('face_labels_full', 'rb'))

all_patch_data = []
n_face = len(face_list)

#%matplotlib tk


#fig02 = plt.figure(figsize=(15,8))
#ax = Axes3D(fig02)   
#print (face_list[40])
#for k in range (10):
#    mvpk = np.where(face_list[k][:,2]==max(face_list[k][:,2]))
    #mvpk = 
#    ax.scatter(face_list[k][:,0]-face_list[k][mvpk,0], 
#               face_list[k][:,1]-face_list[k][mvpk,1],
#               face_list[k][:,2]- face_list[k][mvpk,2])

km01 = KMeans(
        n_clusters=8, init='k-means++',
        n_init=10, max_iter=300, 
        tol=1e-04, random_state=10
    )

mvpk = np.where(face_list[0][:,2]== max(face_list[0][:,2]))
faceo = face_list[0] - face_list[0][mvpk]
    
    
km01 = km01.fit(faceo)
init_centroids = km01.cluster_centers_

#ax.scatter(init_centroids[:,0], init_centroids[:,1], init_centroids[:,2],'r', s=1000)

# %%
    

def process_data(face):
    
    km = KMeans(
        n_clusters=8, init=init_centroids,
        n_init=1, max_iter=300, 
        tol=1e-04, random_state=10
    )

    mvpk = np.where(face[:,2]== max(face[:,2]))
    
    face = face - face[mvpk[0][0]]
    segments = km.fit_predict(face)
    n_patch = len(np.unique(segments)) 
    centroids= km.fit(face).cluster_centers_
    total_features = []
   
    for j in range (n_patch):
        
        patch_features = []
        clusterLabels = []
        featureLabels = []
        
        patch = face[segments == j]
        
        delta_patch = patch - centroids [j]
        
  #      transFeature = spectralFeatures (delta_patch,n_dim = 2, n_neighbor = 10)
   #     df_2Col = transFeature.values
        
        ## Applying GMM on each patch
        gmm = GaussianMixture(n_components = 3, covariance_type= 'diag',random_state=10)
        patch_gmm = gmm.fit(delta_patch)
        patch_w = patch_gmm.weights_
        patch_mu = patch_gmm.means_
        patch_sigma = patch_gmm.covariances_
        
        ## creating data frame for testing
   #     n_features = len(patch_w) + len(patch_mu)*len(patch_mu[1]) #+ len(patch_sigma)*len(patch_sigma[1])
    
        # Features extracted from a single patch
        # 3 + 6 + 6 --> repeated across 8 patches
        patch_features = list(patch_w) + list(patch_mu.ravel())+ list(patch_sigma.ravel())
        
        # concatenating from all patches
        total_features = total_features + patch_features
    # adding features from all patches to the face database 
    all_patch_data.append (total_features)
    return all_patch_data

pool = Pool(5)
results = pool.map(process_data, face_list)

pool.close()
    
#df_3D_face = pd.DataFrame({'Patch_Features':all_patch_data,'Classes':face_labels})                                      

# Encoding class labels 
#le = preprocessing.LabelEncoder() 
#df_3D_face['Labels']= le.fit_transform(df_3D_face['Classes']) 
results
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# TypeError: process_data() takes 1 positional argument but 6882 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-cf00b9873c92> in <module>
#      49
#      50 pool = Pool(5)
# ---> 51 results = [pool.apply(process_data, args=(face)) for face in face_list]
#      52
#      53 #df_3D_face = pd.DataFrame({'Patch_Features':all_patch_data,'Classes':face_labels})
#
# <ipython-input-4-cf00b9873c92> in <listcomp>(.0)
#      49
#      50 pool = Pool(5)
# ---> 51 results = [pool.apply(process_data, args=(face)) for face in face_list]
#      52
#      53 #df_3D_face = pd.DataFrame({'Patch_Features':all_patch_data,'Classes':face_labels})
#
# /opt/anaconda3/lib/python3.7/multiprocessing/pool.py in apply(self, func, args, kwds)
#     259         Pool must be running.
#     260         '''
# --> 261         return self.apply_async(func, args, kwds).get()
#     262
#     263     def map(self, func, iterable, chunksize=None):
#
# /opt/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# TypeError: process_data() takes 1 positional argument but 6882 were given

# %%
from multiprocessing import Pool

def gmm_mix(delta_patch,total_features):
    patch_features = []
    clusterLabels = []
    featureLabels = []


#      transFeature = spectralFeatures (delta_patch,n_dim = 2, n_neighbor = 10)
#     df_2Col = transFeature.values

    ## Applying GMM on each patch
    gmm = GaussianMixture(n_components = 3, covariance_type= 'diag',random_state=10)
    patch_gmm = gmm.fit(delta_patch)
    patch_w = patch_gmm.weights_
    patch_mu = patch_gmm.means_
    patch_sigma = patch_gmm.covariances_

    ## creating data frame for testing
#     n_features = len(patch_w) + len(patch_mu)*len(patch_mu[1]) #+ len(patch_sigma)*len(patch_sigma[1])

    # Features extracted from a single patch
    # 3 + 6 + 6 --> repeated across 8 patches
    patch_features = list(patch_w) + list(patch_mu.ravel())+ list(patch_sigma.ravel())

    # concatenating from all patches
    total_features = total_features + patch_features
    return total_features

all_patch_data =[]
for i,face in enumerate(face_list):
    

    km = KMeans(
        n_clusters=8, init=init_centroids,
        n_init=1, max_iter=300, 
        tol=1e-04, random_state=10
    )

    mvpk = np.where(face[:,2]== max(face[:,2]))
    
    face = face - face[mvpk[0][0]]
    segments = km.fit_predict(face)
    n_patch = len(np.unique(segments)) 
    centroids= km.fit(face).cluster_centers_
    pool = Pool(8)
    results =[]
    for j in range(n_patch):
        patch = face[segments == j]
        delta_patch = patch - centroids [j]
    results = pool.starmap(gmm_mix, [(patch,results)]
    all_patch_data.append(results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-41c68819db2e> in <module>
#      49         patch = face[segments == j]
#      50         delta_patch = patch - centroids [j]
# ---> 51         results = pool.starmap(gmm_mix, delta_patch,results)
#      52     all_patch_data.append(results)
#
# /opt/anaconda3/lib/python3.7/multiprocessing/pool.py in starmap(self, func, iterable, chunksize)
#     274         `func` and (a, b) becomes func(a, b).
#     275         '''
# --> 276         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     277
#     278     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# /opt/anaconda3/lib/python3.7/multiprocessing/pool.py in _map_async(self, func, iterable, mapper, chunksize, callback, error_callback)
#     392         task_batches = Pool._get_tasks(func, iterable, chunksize)
#     393         result = MapResult(self._cache, chunksize, len(iterable), callback,
# --> 394                            error_callback=error_callback)
#     395         self._taskqueue.put(
#     396             (
#
# /opt/anaconda3/lib/python3.7/multiprocessing/pool.py in __init__(self, cache, chunksize, length, callback, error_callback)
#     680         self._value = [None] * length
#     681         self._chunksize = chunksize
# --> 682         if chunksize <= 0:
#     683             self._number_left = 0
#     684             self._event.set()
#
# TypeError: '<=' not supported between instances of 'list' and 'int'

# %%
df_3D_face.to_pickle("all_face_features_lar.pkl")

full_dfx  = var_df.groupby('face_num')['feature_labels'].sum().reset_index()

# Splitting the list into multiple PD columns
full_df = full_dfx.feature_labels.apply(pd.Series)

# Calculating feature variance 
fea_var = full_df.var()

# Constructing -- (n_faceXn_patch) x n_features -- array with variance
var_resh =np.reshape(list(fea_var)*n_face,(n_patch*n_face,n_features))

# Data frame of feature variance
feature_var = pd.DataFrame(data = var_resh,index=var_df.index)

# Concatenate with exiting data frame
final_df= pd.concat([var_df,feature_var],axis =1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-25a57fb34452> in <module>
#       1 df_3D_face.to_pickle("all_face_features_lar.pkl")
#       2
# ----> 3 full_dfx  = var_df.groupby('face_num')['feature_labels'].sum().reset_index()
#       4
#       5 # Splitting the list into multiple PD columns
#
# NameError: name 'var_df' is not defined

# %%
#Cut off 0.001
#fea_indx = np.array([ 0, 1, 2, 3, 5, 7, 15, 16, 17, 18, 20, 21, 22, 30, 31, 
#       32, 36, 45, 46, 47, 49, 51, 60, 61, 62, 63, 64, 65, 66, 67, 75, 76, 
#       77, 78, 80, 82, 90, 91, 94, 105, 106, 107, 108, 110, 111, 112, 113])

#Cut off 0.002
#fea_indx = np.array([ 0, 1, 2, 15, 16, 17, 30, 31, 32, 
#       36, 45, 46, 47, 61, 75, 77, 90, 91, 105, 106, 107])

#fea_indx =np.array([ 1, 2, 15, 30, 31 , 46, 77, 91, 105, 106])

# Load pickle file
df_3D_face = pd.read_pickle("all_face_features_lar.pkl")

xx = df_3D_face['Patch_Features'].to_list() 

data_mat = np.array (xx)

face_labels = df_3D_face['Labels'].to_list() 

n_labels = len(np.unique(face_labels)) 

#dataMatrix = data_mat   # [:, fea_indx]

data_matrix = data_mat# preprocessing.scale(data_mat)

print (len(data_matrix))
f_var = data_matrix[:7]
# Out:
# 350

# %%
## Creating the table content

fea_var = np.var(f_var,axis=0)

j=0
i=0
m=0
n=1

feat_df =pd.DataFrame()
var_df =pd.DataFrame()

while True:
    feat = []
    w = fea_var[m]
    feat.append(w)
    
    mu = fea_var[i+3]+fea_var[i+4]+fea_var[i+5]
    feat.append(mu)
    
    sigma = fea_var[i+12]+fea_var[i+13]+fea_var[i+14]
    feat.append(sigma)
    
    feat_df['Gamma '+str(n)] = [feat]
    
    n+=1# this one is for the coloumns of the dataframe
    j+=1 # this for breaking the loop
    i+=3
    m+=1
    if j%3==0:
        var_df = var_df.append(feat_df,ignore_index=True)
        i+=12
        m+=18
        n=1
        if j == 24:
            break
            

var_df
# Out:
#                                              Gamma 1  \
# 0  [0.0025156674581144583, 328.83572760680636, 36...
# 1  [0.006862982771412938, 379.839453954634, 8512....
# 2  [0.00034562754476548374, 400.4097567834134, 65...
# 3  [0.015243708638424587, 379.93267773167304, 464...
# 4  [0.0034854494989027675, 308.6985323448432, 519...
# 5  [0.013563829024582601, 365.0728341630648, 4972...
# 6  [0.0016733346326793428, 282.3824008456137, 119...
# 7  [0.012342329885543556, 289.2103215300901, 4714...
#
#                                              Gamma 2  \
# 0  [0.002560040791844014, 389.09991967771975, 333...
# 1  [0.020112397167406825, 217.4662553380687, 6954...
# 2  [0.0006175068432006925, 319.38397515251046, 93...
# 3  [0.003356756234678965, 259.99981875436663, 357...
# 4  [0.002403486577491634, 312.09374113674676, 210...
# 5  [0.0027289435494641627, 224.13023814672752, 10...
# 6  [0.0020962507498169455, 131.29581916178748, 15...
# 7  [0.004687538649576603, 183.60967810616074, 555...
#
#                                              Gamma 3
# 0  [0.006308642861868525, 344.14658482618313, 343...
# 1  [0.03400734317031969, 354.27798855668135, 4338...
# 2  [0.0003415534353467235, 195.92697055999102, 12...
# 3  [0.020474407115478016, 290.3068495475598, 1120...
# 4  [0.0040171825750532535, 376.38456038401455, 29...
# 5  [0.007081990516931613, 319.95780065310925, 620...
# 6  [0.0013465044901976263, 393.93220697845607, 61...
# 7  [0.016884733221118536, 259.9299666007508, 6497...

# %%
df = df_3D_face.copy()

# Performing PCA on raw data 
pca = PCA(n_components=5)
pca_result = pca.fit_transform(data_matrix)
df['pca-one'] = pca_result[:,0]
df['pca-two'] = pca_result[:,1] 
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))

plt.figure(figsize=(5,5))
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="Classes",
    palette=sns.color_palette("hls", n_labels),
    data=df,
    legend="full",
    alpha=1.0
)

# Performing t-SNE on raw data
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=10, n_iter=300)
tsne_results = tsne.fit_transform(data_matrix)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

df['tsne-2d-one'] = tsne_results[:,0]
df['tsne-2d-two'] = tsne_results[:,1]

plt.figure(figsize=(5,5))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="Classes",
    palette=sns.color_palette("hls", n_labels),
    data=df,
    legend="full",
    alpha=1.0
)

# Performing t-SNE on PCA data 
tsne_results = tsne.fit_transform(pca_result[:,0:3])
#print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

df['tsne-2d-one'] = tsne_results[:,0]
df['tsne-2d-two'] = tsne_results[:,1]

plt.figure(figsize=(5,5))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="Classes",
    palette=sns.color_palette("hls", n_labels),
    data=df,
    legend="full",
    alpha=1.0
)
# Out:
# Explained variation per principal component: [0.08997684 0.06207466 0.05602716 0.05108088 0.04904935]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 350 samples in 0.001s...
# [t-SNE] Computed neighbors for 350 samples in 0.042s...
# [t-SNE] Computed conditional probabilities for sample 350 / 350
# [t-SNE] Mean sigma: 133.264166
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.195328
# [t-SNE] KL divergence after 300 iterations: 2.162846
# t-SNE done! Time elapsed: 0.3496708869934082 seconds
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 350 samples in 0.000s...
# [t-SNE] Computed neighbors for 350 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 350 / 350
# [t-SNE] Mean sigma: 30.034249
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.080086
# [t-SNE] KL divergence after 300 iterations: 0.807506

# %%
emotions = ['Anger', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
for i in range(len(emotions)):
    n_df = pd.DataFrame()
    for j in range(len(emotions)):
        if j == i:
            continue
        df1 = df.loc[df['Classes']==emotions[i]]
        df2 = df.loc[df['Classes']==emotions[j]]
        n_df = df1.append(df2 , ignore_index=True)

        xx = n_df['Patch_Features'].to_list()
        data_mat = np.array (xx)
        data_matrix = data_mat

        pca = PCA(n_components=20)
        pca_result = pca.fit_transform(data_matrix)
        n_df['pca-one'] = pca_result[:,0]
        n_df['pca-two'] = pca_result[:,1] 
        print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
        tsne = TSNE(n_components=2, verbose=1, perplexity=10, n_iter=300)     
        tsne_results = tsne.fit_transform(pca_result[:,:19])
        n_df['tsne-2d-one'] = tsne_results[:,0]
        n_df['tsne-2d-two'] = tsne_results[:,1]
        plt.figure(figsize=(5,5))
        sns.scatterplot(
            x="tsne-2d-one", y="tsne-2d-two",
            hue="Classes",
            palette=sns.color_palette("hls", 2),
            data=n_df,
            legend="full",
            alpha=1.0
        )
# Out:
# Explained variation per principal component: [0.08880125 0.08329044 0.07382805 0.06304317 0.06076578 0.0511901
#  0.04279704 0.04181816 0.03703247 0.03478436 0.03395635 0.03097558
#  0.02945066 0.02601909 0.02431924 0.02170462 0.02068533 0.01798459
#  0.01703792 0.01590436]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 131.668907
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.332184
# [t-SNE] KL divergence after 300 iterations: 2.199207
# Explained variation per principal component: [0.09749291 0.08015826 0.07276639 0.0646707  0.0588216  0.0503339
#  0.04445707 0.04097586 0.03908245 0.03776058 0.03266643 0.02871523
#  0.0262055  0.02454679 0.02299702 0.02148272 0.01970605 0.01808807
#  0.01724961 0.01678914]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 126.546646
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.622871
# [t-SNE] KL divergence after 300 iterations: 1.985583
# Explained variation per principal component: [0.09372473 0.06975241 0.06467189 0.06358156 0.05439851 0.05058586
#  0.04600169 0.03834153 0.03745535 0.03621991 0.03277194 0.03132279
#  0.02762679 0.0259218  0.02487439 0.02294162 0.02185203 0.02039372
#  0.01925583 0.01886248]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.001s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 159.234190
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 68.842903
# [t-SNE] KL divergence after 300 iterations: 1.831595
# Explained variation per principal component: [0.0998209  0.08392096 0.06411533 0.06240295 0.05818571 0.0512569
#  0.04319532 0.04138295 0.04020375 0.03700967 0.03365171 0.02988297
#  0.02877071 0.0253322  0.02388903 0.02252308 0.01946282 0.01900978
#  0.01691317 0.01568309]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 146.552065
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.599922
# [t-SNE] KL divergence after 300 iterations: 2.061399
# Explained variation per principal component: [0.09392523 0.07951813 0.06476662 0.06044156 0.05323097 0.0504787
#  0.04775474 0.04507175 0.04045808 0.03837255 0.03552194 0.03203283
#  0.0274019  0.02666883 0.02275819 0.02150331 0.02034659 0.01937834
#  0.01718882 0.01638022]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 158.678650
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.307510
# [t-SNE] KL divergence after 300 iterations: 1.793682
# Explained variation per principal component: [0.11304277 0.07580142 0.06693943 0.06110248 0.05972933 0.05026694
#  0.04843835 0.04285007 0.03888503 0.03465591 0.03149815 0.03098104
#  0.02851737 0.02456726 0.02224416 0.02040602 0.0194392  0.01896942
#  0.0168585  0.01537163]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 134.171656
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.400856
# [t-SNE] KL divergence after 300 iterations: 1.936701
# Explained variation per principal component: [0.08880125 0.08329044 0.07382805 0.06304317 0.06076578 0.0511901
#  0.04279704 0.04181816 0.03703247 0.03478436 0.03395635 0.03097558
#  0.02945066 0.02601909 0.02431924 0.02170462 0.02068533 0.01798459
#  0.01703792 0.01590436]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 131.668907
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.187325
# [t-SNE] KL divergence after 300 iterations: 2.202919
# Explained variation per principal component: [0.10928511 0.07158998 0.06441768 0.05913646 0.05870014 0.05086707
#  0.04616861 0.04275163 0.03813669 0.03536839 0.03286438 0.02917144
#  0.02726642 0.02602625 0.02387972 0.02278152 0.02176828 0.01872173
#  0.01854717 0.01602544]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 136.052839
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.250870
# [t-SNE] KL divergence after 300 iterations: 2.051242
# Explained variation per principal component: [0.09506482 0.07297945 0.06828661 0.05538068 0.05446827 0.04827219
#  0.04548075 0.0452477  0.03800649 0.03631133 0.03563826 0.03133383
#  0.02813237 0.02691183 0.02552554 0.0233842  0.02083355 0.02018237
#  0.01927756 0.01617384]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 163.823063
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.942673
# [t-SNE] KL divergence after 300 iterations: 1.770760
# Explained variation per principal component: [0.09331924 0.08730009 0.06448851 0.06004874 0.05315326 0.04815476
#  0.04642266 0.04352938 0.03736093 0.03519229 0.03384566 0.03031053
#  0.02692931 0.02656187 0.02546308 0.02445184 0.02163662 0.01947451
#  0.01885991 0.01751672]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 132.105279
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.462097
# [t-SNE] KL divergence after 300 iterations: 1.866040
# Explained variation per principal component: [0.09849225 0.07337787 0.06774731 0.06214009 0.05148491 0.0511726
#  0.05006687 0.0411018  0.03926054 0.03603685 0.03544265 0.03298
#  0.02826823 0.02555355 0.02429999 0.02191325 0.02103583 0.01844721
#  0.01822348 0.01666451]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 123.291825
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.663818
# [t-SNE] KL divergence after 300 iterations: 2.353316
# Explained variation per principal component: [0.12060886 0.07587173 0.07015883 0.05549389 0.0550219  0.04799322
#  0.04495219 0.04167921 0.04069777 0.03670662 0.03429731 0.0298157
#  0.02778328 0.02486782 0.0235282  0.02237408 0.01906308 0.01791056
#  0.01711242 0.01627917]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 144.833613
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.482903
# [t-SNE] KL divergence after 300 iterations: 1.535176
# Explained variation per principal component: [0.09749291 0.08015826 0.07276639 0.0646707  0.0588216  0.0503339
#  0.04445707 0.04097586 0.03908245 0.03776058 0.03266643 0.02871523
#  0.0262055  0.02454679 0.02299702 0.02148272 0.01970605 0.01808807
#  0.01724961 0.01678914]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 126.546643
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.134964
# [t-SNE] KL divergence after 300 iterations: 1.971868
# Explained variation per principal component: [0.10928511 0.07158998 0.06441768 0.05913646 0.05870014 0.05086707
#  0.04616861 0.04275163 0.03813669 0.03536839 0.03286438 0.02917144
#  0.02726642 0.02602625 0.02387972 0.02278152 0.02176828 0.01872173
#  0.01854717 0.01602544]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 136.052810
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.499802
# [t-SNE] KL divergence after 300 iterations: 1.751908
# Explained variation per principal component: [0.10171399 0.07239614 0.06952062 0.05585255 0.05032385 0.04827727
#  0.04537565 0.04139791 0.04043788 0.03603168 0.03393759 0.03128449
#  0.02971367 0.02783184 0.02596192 0.02289996 0.02224549 0.02055946
#  0.01902172 0.01662586]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 134.857470
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.317993
# [t-SNE] KL divergence after 300 iterations: 1.799312
# Explained variation per principal component: [0.10144738 0.08088305 0.06862537 0.06460501 0.05510958 0.05147552
#  0.04745299 0.04077775 0.03682958 0.03396722 0.03178443 0.02916668
#  0.02639726 0.02389577 0.02371911 0.02191096 0.02100035 0.01954918
#  0.01794602 0.01614326]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 161.631749
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.244293
# [t-SNE] KL divergence after 300 iterations: 1.882696
# Explained variation per principal component: [0.1059412  0.08048712 0.0658611  0.06141295 0.05233371 0.04881159
#  0.04563098 0.04105996 0.03978493 0.03586371 0.03380939 0.03134441
#  0.02938473 0.02586456 0.02420992 0.02119238 0.02045403 0.01863299
#  0.0168444  0.01662293]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 162.268675
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.428574
# [t-SNE] KL divergence after 300 iterations: 2.066918
# Explained variation per principal component: [0.120527   0.07590844 0.06458881 0.06435155 0.05070261 0.04946574
#  0.0475752  0.0435439  0.03735768 0.03471605 0.03286094 0.02878529
#  0.02813619 0.02551455 0.02306956 0.02136262 0.02073429 0.01893056
#  0.01659108 0.0157792 ]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 140.675963
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.363327
# [t-SNE] KL divergence after 300 iterations: 1.959763
# Explained variation per principal component: [0.09372473 0.06975241 0.06467189 0.06358156 0.05439851 0.05058586
#  0.04600169 0.03834153 0.03745535 0.03621991 0.03277194 0.03132279
#  0.02762679 0.0259218  0.02487439 0.02294162 0.02185203 0.02039372
#  0.01925583 0.01886248]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 159.234190
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 68.665611
# [t-SNE] KL divergence after 300 iterations: 1.754468
# Explained variation per principal component: [0.09506482 0.07297945 0.06828661 0.05538068 0.05446827 0.04827219
#  0.04548075 0.0452477  0.03800649 0.03631133 0.03563826 0.03133383
#  0.02813237 0.02691183 0.02552554 0.0233842  0.02083355 0.02018237
#  0.01927756 0.01617384]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.001s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 163.823075
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.050003
# [t-SNE] KL divergence after 300 iterations: 1.995812
# Explained variation per principal component: [0.10171399 0.07239614 0.06952062 0.05585255 0.05032385 0.04827727
#  0.04537565 0.04139791 0.04043788 0.03603168 0.03393759 0.03128449
#  0.02971367 0.02783184 0.02596192 0.02289996 0.02224549 0.02055946
#  0.01902172 0.01662586]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 134.857470
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.863922
# [t-SNE] KL divergence after 300 iterations: 1.666288
# Explained variation per principal component: [0.08956623 0.07174628 0.06465441 0.06048095 0.05527014 0.05029961
#  0.04562149 0.04235217 0.0384477  0.03571428 0.03200777 0.0294894
#  0.02810698 0.02759866 0.0244359  0.02309573 0.02173537 0.01993434
#  0.01898046 0.01820662]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 155.531944
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.737686
# [t-SNE] KL divergence after 300 iterations: 1.727325
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Explained variation per principal component: [0.08955326 0.07035635 0.06182501 0.05666107 0.05515925 0.05094829
#  0.04992443 0.04218891 0.04055089 0.0397175  0.03416521 0.02931164
#  0.02828591 0.02722379 0.02526888 0.02312789 0.022442   0.0206875
#  0.01808682 0.01685627]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 132.765249
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.989059
# [t-SNE] KL divergence after 300 iterations: 1.878530
# Explained variation per principal component: [0.11241255 0.06752244 0.06596576 0.0595481  0.0544839  0.04623057
#  0.04157978 0.04080544 0.0380693  0.03756586 0.03182012 0.03123424
#  0.02910116 0.02776363 0.02606488 0.02234573 0.02116906 0.02023882
#  0.01792021 0.01727299]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 157.502772
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.676170
# [t-SNE] KL divergence after 300 iterations: 1.999484
# Explained variation per principal component: [0.0998209  0.08392096 0.06411533 0.06240295 0.05818571 0.0512569
#  0.04319532 0.04138295 0.04020375 0.03700967 0.03365171 0.02988297
#  0.02877071 0.0253322  0.02388903 0.02252308 0.01946282 0.01900978
#  0.01691317 0.01568309]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.001s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 146.552059
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.970367
# [t-SNE] KL divergence after 300 iterations: 2.299226
# Explained variation per principal component: [0.09331924 0.08730009 0.06448851 0.06004874 0.05315326 0.04815476
#  0.04642266 0.04352938 0.03736093 0.03519229 0.03384566 0.03031053
#  0.02692931 0.02656187 0.02546308 0.02445184 0.02163662 0.01947451
#  0.01885991 0.01751672]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 132.105308
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.289398
# [t-SNE] KL divergence after 300 iterations: 2.122083
# Explained variation per principal component: [0.10144738 0.08088305 0.06862537 0.06460501 0.05510958 0.05147552
#  0.04745299 0.04077775 0.03682958 0.03396722 0.03178443 0.02916668
#  0.02639726 0.02389577 0.02371911 0.02191096 0.02100035 0.01954918
#  0.01794602 0.01614326]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 161.631682
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.090286
# [t-SNE] KL divergence after 300 iterations: 1.952260
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Explained variation per principal component: [0.08956623 0.07174628 0.06465441 0.06048095 0.05527014 0.05029961
#  0.04562149 0.04235217 0.0384477  0.03571428 0.03200777 0.0294894
#  0.02810698 0.02759866 0.0244359  0.02309573 0.02173537 0.01993434
#  0.01898046 0.01820662]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 155.531906
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.411179
# [t-SNE] KL divergence after 300 iterations: 2.033404
# Explained variation per principal component: [0.09760251 0.08213001 0.07519146 0.0620139  0.05428301 0.0463437
#  0.04455356 0.04275517 0.03721315 0.03519189 0.03386756 0.03211738
#  0.02908496 0.02680076 0.02344925 0.0221342  0.02001858 0.01877908
#  0.01839657 0.01640518]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 167.599877
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.541153
# [t-SNE] KL divergence after 300 iterations: 1.822881
# Explained variation per principal component: [0.1109616  0.08123664 0.07083523 0.05715115 0.05248391 0.04833356
#  0.04232604 0.04118425 0.03924155 0.03587204 0.03351801 0.03088675
#  0.02875573 0.02664255 0.02206945 0.02107614 0.01962369 0.01844531
#  0.01733859 0.01670874]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 128.724914
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.142929
# [t-SNE] KL divergence after 300 iterations: 1.737569
# Explained variation per principal component: [0.09392523 0.07951813 0.06476662 0.06044156 0.05323097 0.0504787
#  0.04775474 0.04507175 0.04045808 0.03837255 0.03552194 0.03203283
#  0.0274019  0.02666883 0.02275819 0.02150331 0.02034659 0.01937834
#  0.01718882 0.01638022]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.001s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 158.678613
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.895721
# [t-SNE] KL divergence after 300 iterations: 1.944149
# Explained variation per principal component: [0.09849225 0.07337787 0.06774731 0.06214009 0.05148491 0.0511726
#  0.05006687 0.0411018  0.03926054 0.03603685 0.03544265 0.03298
#  0.02826823 0.02555355 0.02429999 0.02191325 0.02103583 0.01844721
#  0.01822348 0.01666451]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 123.291801
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.890907
# [t-SNE] KL divergence after 300 iterations: 1.704997
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Explained variation per principal component: [0.1059412  0.08048712 0.0658611  0.06141295 0.05233371 0.04881159
#  0.04563098 0.04105996 0.03978493 0.03586371 0.03380939 0.03134441
#  0.02938473 0.02586456 0.02420992 0.02119238 0.02045403 0.01863299
#  0.0168444  0.01662293]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 162.268651
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.622162
# [t-SNE] KL divergence after 300 iterations: 1.606830
# Explained variation per principal component: [0.08955326 0.07035635 0.06182501 0.05666107 0.05515925 0.05094829
#  0.04992443 0.04218891 0.04055089 0.0397175  0.03416521 0.02931164
#  0.02828591 0.02722379 0.02526888 0.02312789 0.022442   0.0206875
#  0.01808682 0.01685627]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 132.765227
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.136292
# [t-SNE] KL divergence after 300 iterations: 1.911475
# Explained variation per principal component: [0.09760251 0.08213001 0.07519146 0.0620139  0.05428301 0.0463437
#  0.04455356 0.04275517 0.03721315 0.03519189 0.03386756 0.03211738
#  0.02908496 0.02680076 0.02344925 0.0221342  0.02001858 0.01877908
#  0.01839657 0.01640518]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 167.599842
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.060654
# [t-SNE] KL divergence after 300 iterations: 1.927813
# Explained variation per principal component: [0.12195656 0.07310386 0.06498948 0.05861876 0.05058839 0.04937907
#  0.04331153 0.04028487 0.03910141 0.03573625 0.03272118 0.03000949
#  0.02823345 0.02649693 0.02573099 0.0235972  0.02115291 0.01898896
#  0.01697821 0.01617656]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 179.472246
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.971802
# [t-SNE] KL divergence after 300 iterations: 1.962413
# Explained variation per principal component: [0.11304277 0.07580142 0.06693943 0.06110248 0.05972933 0.05026694
#  0.04843835 0.04285007 0.03888503 0.03465591 0.03149815 0.03098104
#  0.02851737 0.02456726 0.02224416 0.02040602 0.0194392  0.01896942
#  0.0168585  0.01537163]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 134.171670
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.411224
# [t-SNE] KL divergence after 300 iterations: 2.018583
# Explained variation per principal component: [0.12060886 0.07587173 0.07015883 0.05549389 0.0550219  0.04799322
#  0.04495219 0.04167921 0.04069777 0.03670662 0.03429731 0.0298157
#  0.02778328 0.02486782 0.0235282  0.02237408 0.01906308 0.01791056
#  0.01711242 0.01627917]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 144.833586
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.222961
# [t-SNE] KL divergence after 300 iterations: 2.241662
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Explained variation per principal component: [0.120527   0.07590844 0.06458881 0.06435155 0.05070261 0.04946574
#  0.0475752  0.0435439  0.03735768 0.03471605 0.03286094 0.02878529
#  0.02813619 0.02551455 0.02306956 0.02136262 0.02073429 0.01893056
#  0.01659108 0.0157792 ]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 140.675935
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.664795
# [t-SNE] KL divergence after 300 iterations: 2.025460
# Explained variation per principal component: [0.11241255 0.06752244 0.06596576 0.0595481  0.0544839  0.04623057
#  0.04157978 0.04080544 0.0380693  0.03756586 0.03182012 0.03123424
#  0.02910116 0.02776363 0.02606488 0.02234573 0.02116906 0.02023882
#  0.01792021 0.01727299]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.001s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 157.502772
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.960564
# [t-SNE] KL divergence after 300 iterations: 1.866396
# Explained variation per principal component: [0.1109616  0.08123664 0.07083523 0.05715115 0.05248391 0.04833356
#  0.04232604 0.04118425 0.03924155 0.03587204 0.03351801 0.03088675
#  0.02875573 0.02664255 0.02206945 0.02107614 0.01962369 0.01844531
#  0.01733859 0.01670874]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 128.724914
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.650024
# [t-SNE] KL divergence after 300 iterations: 2.068125
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Explained variation per principal component: [0.12195656 0.07310386 0.06498948 0.05861876 0.05058839 0.04937907
#  0.04331153 0.04028487 0.03910141 0.03573625 0.03272118 0.03000949
#  0.02823345 0.02649693 0.02573099 0.0235972  0.02115291 0.01898896
#  0.01697821 0.01617656]
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 179.472257
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.069778
# [t-SNE] KL divergence after 300 iterations: 1.715010
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import ( pipeline, preprocessing, linear_model)
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.utils.multiclass import unique_labels
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import multiprocessing as mp
from pathos.multiprocessing import ProcessingPool as Pool



#70% taining, 20% validating 10% testing
# 10x2 nested cross-validation 
# K-fold cross-validation - 1 fold -, 2-fold, average 
# 80% - 20%

print ('Number of features', len(data_matrix[1]))

# 10-fold cross-validation
# Each fold test - 35, train - 315
#Kaggle 
nfolds = 10
clf = GradientBoostingClassifier(n_estimators= 5,
                         #       class_weight = "balanced",
                                random_state=42#,cache_size=20000
                               # n_jobs=1
                               )

    
param_grid = {
                      "clf__n_estimators":[10, 20, 30, 40, 50],
              "clf__min_samples_split": [2, 5, 10],
            "clf__learning_rate":[0.1, .02, 0.5],
             "clf__max_depth": [2, 5, 10, 15]
             }
    
    
        
kfold = StratifiedKFold(n_splits= nfolds, random_state= 42, shuffle=True)
    
pipe = pipeline.Pipeline([#('scl', preprocessing.StandardScaler()),
                                 ('clf', clf)])
    
 

fold_auc = []
testPredict = []
Stest = []

def func(df):
    return df.shape

cores=mp.cpu_count()
pool = Pool(cores)

#df_split = np.array_split(df, cores, axis=0)

for k, (train, test) in enumerate (kfold.split(data_matrix,face_labels)):
         
        # Accumulating training fold data and labels
        trfold = [data_matrix [x] for x in train]
        trSen  = [face_labels[x] for x in train]
        
       
        # Accumulating test fold data and labels
        tsfold = [data_matrix[x] for x in test]
        tsSen = [face_labels[x] for x in test]
        
        
        
        gsModel = GridSearchCV(estimator=pipe, 
                                  param_grid = param_grid, n_jobs=1,
                                  scoring = 'accuracy', cv = 2)
         
        
        # training the model 
        trModel = gsModel.fit(trfold,trSen)
        
        bestModel = trModel.best_estimator_
        
        testPred =  bestModel.predict(tsfold)
        
        ##### Predict Probability ############
        
        probas =  bestModel.predict_proba(tsfold)
        
        
        roc_auc =[]
        for t in range (len(np.unique(face_labels))):
            
            fpr, tpr, _ = roc_curve(tsSen,probas[:,t], pos_label=t)        
            roc_auc.append( auc(fpr,tpr))
            
        print (roc_auc)
        
        fold_auc.append (np.mean(roc_auc))
        
        
        testPredict.extend (testPred)
        Stest.extend (tsSen)
        
       # print ('Accuracy is:',accuracy_score( tsSen, testPred))
    
#    print(datetime.datetime.now().time())
print ('Mean 10-fold AUC', np.mean(fold_auc))
print ('Std 10-fold AUC', np.std(fold_auc))
    
#    return Stest, testPredict
# Out:
# Number of features 168
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c5ccfb760f48> in <module>
#      82
#      83         # training the model
# ---> 84         trModel = gsModel.fit(np.vstack(pool.map(func, tr_split)),trSen)
#      85
#      86         bestModel = trModel.best_estimator_
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     648             refit_metric = 'score'
#     649
# --> 650         X, y, groups = indexable(X, y, groups)
#     651         fit_params = _check_fit_params(X, fit_params)
#     652
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     246     """
#     247     result = [_make_indexable(X) for X in iterables]
# --> 248     check_consistent_length(*result)
#     249     return result
#     250
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
#     211         raise ValueError("Found input variables with inconsistent numbers of"
# --> 212                          " samples: %r" % [int(l) for l in lengths])
#     213
#     214
#
# ValueError: Found input variables with inconsistent numbers of samples: [8, 315]

# %%
def showAccuracy (Stest, testPredict):
    
    
    #Stest = tsSen
    cMatrix = confusion_matrix(Stest,testPredict)

    # Converts each value in the matrix into a percentage/float-value
    cMatrix = cMatrix.astype('float') / cMatrix.sum(axis=1)[:, np.newaxis]

    # Convert this list into a numpy array
    Sent_test = np.asarray(Stest, dtype=np.int)


    boxPlot, ax = plt.subplots()

    # The tick labels for the box-plot
    sent_label = ['Anger', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise'] 
    sent_label = np.asarray(sent_label, dtype=np.str)
    sent_label = sent_label[unique_labels(Stest, testPredict)]

    # (cmap = plt.cm.Greens) represents the colors/shades used for the plot
    im = ax.imshow(cMatrix, interpolation='nearest', cmap=plt.cm.Greens)
    ax.figure.colorbar(im, ax=ax)

    # Configures the labels and tick marks of the box-plot
    ax.set(xticks=np.arange(cMatrix.shape[1]),
       yticks=np.arange(cMatrix.shape[0]),
       
       # Label the ticks with their respective sentiment
       xticklabels=sent_label, yticklabels=sent_label,
       
       # Label the sides
       title='Confusion Matrix',
       ylabel='True Expression',
       xlabel='Predicted Expression')

    # Rotates and aligns the tick labels to be upright and centered
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f'
    thresh = cMatrix.max() / 2.

    for i in range(cMatrix.shape[0]):
        for j in range(cMatrix.shape[1]):
            ax.text(j, i, format(cMatrix[i, j], fmt),
                ha="center", va="center",
                color="white" if cMatrix[i, j] > thresh else "black")



    # A report of something, not sure though...
    print(classification_report(Stest,testPredict))  

    # The overall accuracy of our test
    print('• Overall accuracy of the prediction/classifier model: ', accuracy_score(Sent_test, testPredict))

    # Prints the fancy box-plot
    boxPlot.tight_layout()

# %%
showAccuracy (Stest, testPredict)
